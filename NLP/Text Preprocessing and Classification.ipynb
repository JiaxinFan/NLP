# %% [markdown]
# # Assignment 1: Preprocessing and Text Classification

# %% [markdown]
# Student Name:JIAXIN FAN
#
# Student ID:1163511

# %% [markdown]
# # General Info
#
# <b>Due date</b>: Sunday, 27 March 2022 5pm
#
# <b>Submission method</b>: Canvas submission
#
# <b>Submission materials</b>: completed copy of this iPython notebook
#
# <b>Late submissions</b>: -10% per day (both week and weekend days counted)
#
# <b>Marks</b>: 9% of mark for class (with 8% on correctness + 1% on quality and efficiency of your code)
#
# <b>Materials</b>: See "Using Jupyter Notebook and Python" page on Canvas (under Modules>Resources) for information on the basic setup required for this class, including an iPython notebook viewer and the python packages NLTK, Numpy, Scipy, Matplotlib, Scikit-Learn, and Gensim. We recommend installing all the data for NLTK, since you will need various parts of it to complete this assignment. You can also use any Python built-in packages, but do not use any other 3rd party packages (the packages listed above are all fine to use); if your iPython notebook doesn't run on the marker's machine, you will lose marks. <b> You should use Python 3</b>.
#
# To familiarize yourself with NLTK, here is a free online book:  Steven Bird, Ewan Klein, and Edward Loper (2009). <a href=https://www.nltk.org/book/>Natural Language Processing with Python</a>. O'Reilly Media Inc. You may also consult the <a href=https://www.nltk.org/api/nltk.html>NLTK API</a>.
#
# <b>Evaluation</b>: Your iPython notebook should run end-to-end without any errors in a reasonable amount of time, and you must follow all instructions provided below, including specific implementation requirements and instructions for what needs to be printed (please avoid printing output we don't ask for). You should edit the sections below where requested, but leave the rest of the code as is. You should leave the output from running your code in the iPython notebook you submit, to assist with marking. The amount each question is worth is explicitly given.
#
# You will be marked not only on the correctness of your methods, but also the quality and efficency of your code: in particular, you should be careful to use Python built-in functions and operators when appropriate and pick descriptive variable names that adhere to <a href="https://www.python.org/dev/peps/pep-0008/">Python style requirements</a>. If you think it might be unclear what you are doing, you should comment your code to help the marker make sense of it.
#
# <b>Updates</b>: Any major changes to the assignment will be announced via Canvas. Minor changes and clarifications will be announced on the discussion board; we recommend you check it regularly.
#
# <b>Academic misconduct</b>: For most people, collaboration will form a natural part of the undertaking of this homework, and we encourge you to discuss it in general terms with other students. However, this ultimately is still an individual task, and so reuse of code or other instances of clear influence will be considered cheating. We will be checking submissions for originality and will invoke the University’s <a href="http://academichonesty.unimelb.edu.au/policy.html">Academic Misconduct policy</a> where inappropriate levels of collusion or plagiarism are deemed to have taken place.

# %% [markdown]
# # Overview
#
# In this homework, you'll be working with a collection of tweets. The task is to predict the geolocation (country) where the tweet comes from. This homework involves writing code to preprocess data and perform text classification.

# %% [markdown]
# # Preprocessing (4 marks)

# %% [markdown]
# **Instructions**: Download the data (as1-data.json) from Canvas and put it in the same directory as this iPython notebook. Run the code below to load the json data. This produces two objects, `x` and `y`, which contains a list of  tweets and corresponding country labels (it uses the standard [2 letter country code](https://www.iban.com/country-codes)) respectively. **No implementation is needed.**

# %%
import json

x = []
y = []
data = json.load(open("as1-data.json"))
for k, v in data.items():
    x.append(k)
    y.append(v)
    
print("Number of tweets =", len(x))
print("Number of labels =", len(y))
print("\nSamples of data:")
for i in range(10):
    print("Country =", y[i], "\tTweet =", x[i])
    
assert(len(x) == 943)
assert(len(y) == 943)
# Out:
# Number of tweets = 943
# Number of labels = 943
#
# Samples of data:
# Country = us 	Tweet = @Addictd2Success thx u for following
# Country = us 	Tweet = Let's just say, if I were to ever switch teams, Khalesi would be top of the list. #girlcrush
# Country = ph 	Tweet = Taemin jonghyun!!! Your birits make me go~ http://t.co/le8z3dntlA
# Country = id 	Tweet = depart.senior 👻 rapat perdana (with Nyayu, Anita, and 8 others at Ruang Aescullap FK Unsri Madang) — https://t.co/swRALlNkrQ
# Country = ph 	Tweet = Done with internship with this pretty little lady!  (@ Metropolitan Medical Center w/ 3 others) [pic]: http://t.co/1qH61R1t5r
# Country = gb 	Tweet = Wow just Boruc's clanger! Haha Sunday League stuff that, Giroud couldn't believe his luck! #clown
# Country = my 	Tweet = I'm at Sushi Zanmai (Petaling Jaya, Selangor) w/ 5 others http://t.co/bcNobykZ
# Country = us 	Tweet = Mega Fest!!!! Its going down🙏🙌  @BishopJakes
# Country = gb 	Tweet = @EllexxxPharrell wow love the pic babe xx
# Country = us 	Tweet = You have no clue how much you hurt me

# %% [markdown]
# ### Question 1 (1.0 mark)
#
# **Instructions**: Next we need to preprocess the collected tweets to create a bag-of-words representation (based on frequency). The preprocessing steps required here are: (1) tokenize each tweet into individual word tokens (using NLTK `TweetTokenizer`); (2) lowercase all words; (3) remove any word that does not contain any English alphabets (e.g. {_hello_, _#okay_, _abc123_} would be kept, but not {_123_, _!!_}) and (4) remove stopwords (based on NLTK `stopwords`). An empty tweet (after preprocessing) and its country label should be **excluded** from the output (`x_processed` and `y_processed`).
#
# **Task**: Complete the `preprocess_data(data, labels)` function. The function takes **a list of tweets** and **a corresponding list of country labels** as input, and returns **two lists**. For the first list, each element is a bag-of-words representation of a tweet (represented using a python dictionary). For the second list, each element is a corresponding country label. Note that while we do not need to preprocess the country labels (`y`), we need to have a new output list (`y_processed`) because some tweets maybe removed after the preprocessing (due to having an empty set of bag-of-words).
#
# **Check**: Use the assertion statements in <b>"For your testing"</b> below for the expected output.

# %%
# test=[]
# for i in range(10):
#     test.append(x[i])
# print(len(test))
# print(test)
# print("")
# print(preprocess_data(test,y))

# %%
import nltk
import re
from nltk.tokenize import TweetTokenizer
from collections import Counter
from nltk.corpus import stopwords
stopwords = set(stopwords.words('english')) 

def preprocess_data(data, labels):
    tt = TweetTokenizer()
    tokenized_sentence=[]
    tokenterm=[]
    newlabels=[]
    for i in range (len(data)):
        tokenterm=tt.tokenize(data[i].lower())
        regular=[]
        for j in range (len(tokenterm)):
            if re.search('[a-zA-Z]', tokenterm[j]):
                if  not tokenterm[j] in stopwords:
                    regular.append(tokenterm[j])
        if regular:
            
            tokenized_sentence.append(dict(Counter(regular)))
            newlabels.append(labels[i])
            
    return tokenized_sentence,newlabels



x_processed, y_processed = preprocess_data(x, y)

print("Number of preprocessed tweets =", len(x_processed))
print("Number of preprocessed labels =", len(y_processed))
print("\nSamples of preprocessed data:")
for i in range(10):
    print("Country =", y_processed[i], "\tTweet =", x_processed[i])
# Out:
# Number of preprocessed tweets = 943
# Number of preprocessed labels = 943
#
# Samples of preprocessed data:
# Country = us 	Tweet = {'@addictd2success': 1, 'thx': 1, 'u': 1, 'following': 1}
# Country = us 	Tweet = {"let's": 1, 'say': 1, 'ever': 1, 'switch': 1, 'teams': 1, 'khalesi': 1, 'would': 1, 'top': 1, 'list': 1, '#girlcrush': 1}
# Country = ph 	Tweet = {'taemin': 1, 'jonghyun': 1, 'birits': 1, 'make': 1, 'go': 1, 'http://t.co/le8z3dntla': 1}
# Country = id 	Tweet = {'depart.senior': 1, 'rapat': 1, 'perdana': 1, 'nyayu': 1, 'anita': 1, 'others': 1, 'ruang': 1, 'aescullap': 1, 'fk': 1, 'unsri': 1, 'madang': 1, 'https://t.co/swrallnkrq': 1}
# Country = ph 	Tweet = {'done': 1, 'internship': 1, 'pretty': 1, 'little': 1, 'lady': 1, 'metropolitan': 1, 'medical': 1, 'center': 1, 'w': 1, 'others': 1, 'pic': 1, 'http://t.co/1qh61r1t5r': 1}
# Country = gb 	Tweet = {'wow': 1, "boruc's": 1, 'clanger': 1, 'haha': 1, 'sunday': 1, 'league': 1, 'stuff': 1, 'giroud': 1, 'believe': 1, 'luck': 1, '#clown': 1}
# Country = my 	Tweet = {"i'm": 1, 'sushi': 1, 'zanmai': 1, 'petaling': 1, 'jaya': 1, 'selangor': 1, 'w': 1, 'others': 1, 'http://t.co/bcnobykz': 1}
# Country = us 	Tweet = {'mega': 1, 'fest': 1, 'going': 1, '@bishopjakes': 1}
# Country = gb 	Tweet = {'@ellexxxpharrell': 1, 'wow': 1, 'love': 1, 'pic': 1, 'babe': 1, 'xx': 1}
# Country = us 	Tweet = {'clue': 1, 'much': 1, 'hurt': 1}

# %% [markdown]
# **For your testing**:

# %%
assert(len(x_processed) == len(y_processed))
assert(len(x_processed) > 800)

# %% [markdown]
# **Instructions**: Hashtags (i.e. topic tags which start with #) pose an interesting tokenisation problem because they often include multiple words written without spaces or capitalization. Run the code below to collect all unique hashtags in the preprocessed data. **No implementation is needed.**

# %%
def get_all_hashtags(data):
    hashtags = set([])
    for d in data:
        for word, frequency in d.items():
            if word.startswith("#") and len(word) > 1:
                hashtags.add(word)
    return hashtags

hashtags = get_all_hashtags(x_processed)
print("Number of hashtags =", len(hashtags))
print(sorted(hashtags))
# Out:
# Number of hashtags = 425
# ['#100percentpay', '#1stsundayofoctober', '#1yearofalmostisneverenough', '#2011prdctn', '#2015eebritishfilmacademyawards', '#2k16', '#2littlebirds', '#365picture', '#5sosacousticatlanta', '#5sosfam', '#8thannualpubcrawl', '#affsuzukicup', '#aflpowertigers', '#ahimacon14', '#aim20', '#airasia', '#allcity', '#alliswell', '#allwedoiscurls', '#amazing', '#anferneehardaway', '#ariona', '#art', '#arte', '#artwork', '#ashes', '#asian', '#asiangirl', '#askcrawford', '#askherforfback', '#askolly', '#asksteven', '#at', '#australia', '#awesome', '#awesomepict', '#barcelona', '#bart', '#bayofislands', '#beautiful', '#bedimages', '#bell', '#beringmy', '#bettybooppose', '#bff', '#big', '#bigbertha', '#bigbreakfast', '#blackhat', '#blessedmorethanicanimagine', '#blessedsunday', '#blogtourambiente', '#bluemountains', '#bonekachika', '#boomtaob', '#booyaa', '#bored', '#boredom', '#bradersisterhood', '#breaktime', '#breedingground', '#bringithomemy', '#brooksengland', '#burgers', '#butitsalsokindofaphone', '#bye', '#camera', '#canadaelections', '#cbb', '#cbcolympics', '#cctv', '#cdnpoli', '#celebritycrush', '#chargers', '#chocolate', '#ciosummit', '#cleansidewalk', '#clown', '#coffeespoonart', '#colts', '#confused', '#cornell', '#country', '#craftbeer', '#creative', '#crepes', '#cumannanya', '#danny4mayor', '#data', '#date', '#datingsiteforyou', '#dearmind', '#deed', '#delightful', '#dennisrodman', '#design', '#devacurl', '#die', '#difd', '#diner', '#dinner', '#dragoncon', '#dus', '#dynamounlock', '#earrings', '#eeeeeehhh', '#election2015', '#electriccircus2014', '#endomondo', '#engine', '#english', '#europapark', '#excitables', '#fabulous', '#factorycampus', '#fall', '#familydinner', '#ff', '#fire', '#flambees', '#flashback', '#fly', '#focusateneo', '#followher', '#followme', '#foodporn', '#fotografías', '#fotorus', '#four', '#freaks', '#friday', '#fridaynight', '#fried', '#friends', '#friendshipflow', '#fries', '#frozenyoghurt', '#fun', '#future', '#galaxy', '#getfreetattooaviciipasses', '#girl', '#girlcrush', '#girls', '#givesmehope', '#goingout', '#google', '#graduated', '#grafunkthiremepls', '#grammyfans', '#grandmarnier', '#greenfood', '#grilled', '#gudnytall', '#gunner', '#gym', '#handbuiltbicycle', '#happybirthdaysandarapark', '#happyfriday', '#harimaumalaya', '#hb60', '#hens', '#hippy', '#holiday', '#hollywoodmusicawards', '#homemadegranola', '#hometomama', '#hot', '#hungergames', '#hungry', '#icu', '#ididntchoosethestudentlifeitchoseme', '#iloveyou', '#imsobored', '#imsosore', '#innoretail', '#insanity', '#insightmedia', '#insightmediasingapore', '#instaframeplus', '#instagood', '#instalook', '#isibaya', '#javaboy', '#jed', '#jewelry', '#jo', '#jordaan', '#jrsurfboards', '#justshare', '#kllive', '#ladygaga', '#latepost', '#laugh', '#laundryservice', '#lazysunday', '#learningcommunties', '#lebedeintennis', '#letmesleep', '#lfc', '#lgbt', '#life', '#lipstickfree', '#littlemonsters', '#loadsoffun', '#lol', '#longranger', '#lotsoflove', '#love', '#lovers', '#lovethisgirl', '#lovevibes', '#lte', '#magazinesandtvscreens', '#magic', '#makeupfree', '#makingemuklajawabnya', '#mamajeanneandme', '#mancrush', '#march', '#massacreconspiracy', '#mauce', '#mavic', '#me', '#meetup', '#melbourne', '#michaelkors', '#mindfulness', '#mkmedi', '#mobile', '#morning', '#mountains', '#movies', '#mtlnewtech', '#mtvhottest', '#mushroom', '#music', '#mustfollow', '#mwc14', '#mybabyemilia', '#myfriendsarebetterthanyours', '#nced', '#ncga', '#ncpol', '#nevergetsold', '#new', '#newlooks', '#newrecord', '#nextlevel', '#nfl', '#nickryrie', '#nochillzone', '#nofilter', '#notersnew2014', '#notreally', '#np', '#nye', '#of', '#offtochurch', '#ohyeah', '#oilandgas', '#olah', '#on', '#oops', '#openspace', '#oscars', '#oui', '#palacefansinthemorning', '#panther', '#panthers', '#partyhardpartyy', '#pats', '#pechanga', '#penny', '#peperoni', '#peppermoney', '#photo', '#photoby', '#photography', '#pic', '#pll', '#pmattheashes', '#pop-up', '#positivity', '#potd', '#procrastina ...

# %% [markdown]
# ### Question 2 (1.0 mark)
#
# **Instructions**: Our task here to tokenize the hashtags, by implementing the **MaxMatch algorithm** discussed in class.
#
# NLTK has a list of words that you can use for matching, see starter code below (`words`). Be careful about efficiency with respect to doing word lookups. One extra challenge you have to deal with is that the provided list of words (`words`) includes only lemmas: your MaxMatch algorithm should match inflected forms by converting them into lemmas using the NLTK lemmatizer before matching (provided by the function `lemmatize(word)`). Note that the list of words (`words`) is the only source that you'll use for matching (i.e. you do not need to find  other external word lists). If you are unable to make any longer match, your code should default to matching a single letter.
#
# For example, given "#newrecord", the algorithm should produce: \["#", "new", "record"\].
#
# **Task**: Complete the `tokenize_hashtags(hashtags)` function by implementing the MaxMatch algorithm. The function takes as input **a set of hashtags**, and returns **a dictionary** where key="hashtag" and value="a list of tokenised words".
#
# **Check**: Use the assertion statements in <b>"For your testing"</b> below for the expected output.

# %%
from nltk.corpus import wordnet

lemmatizer = nltk.stem.wordnet.WordNetLemmatizer()
words = set(nltk.corpus.words.words()) #a list of words provided by NLTK
words = set([ word.lower() for word in words ]) #lowercase all the words for better matching

def lemmatize(word):
    lemma = lemmatizer.lemmatize(word,'v')
    if lemma == word:
        lemma = lemmatizer.lemmatize(word,'n')
    return lemma

def tokenize_sentence(sentence):  
    n = len(sentence)
    if sentence == '':
        return []
    for i in range(n - 1):
        firstword = lemmatize(sentence[:n - i])
        remainder = sentence[n - i:]
        if firstword in words:
            return [firstword] + tokenize_sentence(remainder)
    # no word was found, so make a one-character word.
    firstword = sentence[0]
    remainder = sentence[1:]
    return [firstword] + tokenize_sentence(remainder)

def tokenize_hashtags(hashtag):
    hashtag=list(sorted(hashtag))
    dic={}
    for i in range(len(hashtag)):
        dic[hashtag[i]]= tokenize_sentence(hashtag[i])
    return dic
    
    
    



# #tokenise hashtags with MaxMatch
tokenized_hashtags = tokenize_hashtags(hashtags)

#print results
for k, v in sorted(tokenized_hashtags.items())[-30:]:
    print(k, v)
# Out:
# #vanilla ['#', 'vanilla']
# #vca ['#', 'v', 'ca']
# #vegan ['#', 'vega', 'n']
# #veganfood ['#', 'vega', 'n', 'food']
# #vegetables ['#', 'vegetable']
# #vegetarian ['#', 'vegetarian']
# #video ['#', 'video']
# #vma ['#', 'v', 'ma']
# #voteonedirection ['#', 'vote', 'one', 'direction']
# #vsco ['#', 'v', 'c', 'o']
# #vscocam ['#', 'v', 'coca', 'm']
# #walking ['#', 'walk']
# #watch ['#', 'watch']
# #weare90s ['#', 'wear', 'e', '9', '0', 's']
# #wearesocial ['#', 'wear', 'o', 'c', 'i', 'al']
# #white ['#', 'white']
# #wings ['#', 'wing']
# #wok ['#', 'wo', 'k']
# #wood ['#', 'wood']
# #work ['#', 'work']
# #workmates ['#', 'work', 'mat']
# #world ['#', 'world']
# #worldcup2014 ['#', 'world', 'cup', '2', '0', '1', '4']
# #yellow ['#', 'yellow']
# #yiamas ['#', 'y', 'i', 'ama', 's']
# #ynwa ['#', 'yn', 'wa']
# #youtube ['#', 'you', 'tube']
# #yummy ['#', 'yummy']
# #yws13 ['#', 'y', 'w', '1', '3']
# #zweihandvollfarm ['#', 'z', 'wei', 'hand', 'vol', 'l', 'farm']

# %% [markdown]
# **For your testing:**

# %%
assert(len(tokenized_hashtags) == len(hashtags))
assert(tokenized_hashtags["#newrecord"] == ["#", "new", "record"])

# %%
def tokenize_sentence_rev(sentence):  
    n = len(sentence)
    if sentence == '':
        return []
    for i in range(n - 1):
        firstword = lemmatize(sentence[i:n ])
        remainder = sentence[:i]
        if firstword in words:
            return  tokenize_sentence_rev(remainder)+[firstword] 
    # no word was found, so make a one-character word.
    firstword = sentence[0]
    remainder = sentence[1:]
    return [firstword] + tokenize_sentence_rev(remainder)

# %%
# print(tokenize_sentence_rev("#newrecord"))

# %% [markdown]
# ### Question 3 (1.0 mark)
#
# **Instructions**: Our next task is to tokenize the hashtags again, but this time using a **reversed version of the MaxMatch algorithm**, where matching begins at the end of the hashtag and progresses backwards (e.g. for <i>#helloworld</i>, we would process it right to left, starting from the last character <i>d</i>). Just like before, you should use the provided word list (`words`) for word matching.
#
# **Task**: Complete the `tokenize_hashtags_rev(hashtags)` function by the MaxMatch algorithm. The function takes as input **a set of hashtags**, and returns **a dictionary** where key="hashtag" and value="a list of tokenised words".
#
# **Check**: Use the assertion statements in <b>"For your testing"</b> below for the expected output.

# %%
def tokenize_sentence_rev(sentence):  
    n = len(sentence)
    if sentence == '':
        return []
    for i in range(n - 1):
        firstword = lemmatize(sentence[i:n ])
        remainder = sentence[:i]
        if firstword in words:
            return  tokenize_sentence_rev(remainder)+[firstword] 
    # no word was found, so make a one-character word.
    firstword = sentence[-1]
    remainder = sentence[:-1]
    return  tokenize_sentence_rev(remainder) + [firstword] 




def tokenize_hashtags_rev(hashtag):
    hashtag=list(sorted(hashtag))
    dic={}
    for i in range(len(hashtag)):
        dic[hashtag[i]]= tokenize_sentence_rev(hashtag[i])
    return dic

    
#tokenise hashtags with the reversed version of MaxMatch
tokenized_hashtags_rev = tokenize_hashtags_rev(hashtags)

#print results
for k, v in sorted(tokenized_hashtags_rev.items())[-30:]:
    print(k, v)
# Out:
# #vanilla ['#', 'vanilla']
# #vca ['#', 'v', 'ca']
# #vegan ['#', 'v', 'e', 'gin']
# #veganfood ['#', 'v', 'e', 'gin', 'food']
# #vegetables ['#', 'vegetable']
# #vegetarian ['#', 'vegetarian']
# #video ['#', 'video']
# #vma ['#', 'v', 'ma']
# #voteonedirection ['#', 'vote', 'one', 'direction']
# #vsco ['#', 'v', 'c', 'o']
# #vscocam ['#', 'v', 'c', 'o', 'cam']
# #walking ['#', 'walk']
# #watch ['#', 'watch']
# #weare90s ['#', 'we', 'be', '9', '0', 's']
# #wearesocial ['#', 'we', 'be', 'social']
# #white ['#', 'white']
# #wings ['#', 'wing']
# #wok ['#', 'w', 'ok']
# #wood ['#', 'wood']
# #work ['#', 'work']
# #workmates ['#', 'work', 'mat']
# #world ['#', 'world']
# #worldcup2014 ['#', 'world', 'cup', '2', '0', '1', '4']
# #yellow ['#', 'yellow']
# #yiamas ['#', 'y', 'i', 'a', 'ma']
# #ynwa ['#', 'yn', 'wa']
# #youtube ['#', 'you', 'tube']
# #yummy ['#', 'yummy']
# #yws13 ['#', 'y', 'w', '1', '3']
# #zweihandvollfarm ['#', 'z', 'wei', 'hand', 'vol', 'l', 'farm']

# %% [markdown]
# **For your testing:**

# %%
assert(len(tokenized_hashtags_rev) == len(hashtags))
assert(tokenized_hashtags_rev["#newrecord"] == ["#", "new", "record"])

# %% [markdown]
# ### Question 4 (1.0 mark)
#
# **Instructions**: The two versions of MaxMatch will produce different results for some of the hashtags. For a hastag that has different results, our task here is to use a **unigram language model** (lecture 3) to score them to see which is better. Recall that in a unigram language model we compute P(<i>#</i>, <i>hello</i>, <i>world</i> = P(<i>#</i>)\*P(<i>hellow</i>)\*P(<i>world</i>).
#
# You should: (1) use the NLTK's Brown corpus (`brown_words`) for collecting word frequencies (note: the words are already tokenised so no further tokenisation is needed); (2) lowercase all words in the corpus; (3) use add-one smoothing when computing the unigram probabilities; and (4) work in the log space to prevent numerical underflow.
#
# **Task**: Build a unigram language model with add-one smoothing using the word counts from the Brown corpus. Iterate through the hashtags, and for each hashtag where MaxMatch and reversed MaxMatch produce different results, print the following: (1) the hashtag; (2) the results produced by MaxMatch and reversed MaxMatch; and (3) the log probability of each result as given by the unigram language model. Note: you **do not** need to print the hashtags where MaxMatch and reversed MaxMatch produce the same results.
#
# An example output:
# ```
# 1. #abcd
# MaxMatch = [#, a, bc, d]; LogProb = -2.3
# Reversed MaxMatch = [#, a, b, cd]; LogProb = -3.5
#
# 2. #efgh
# MaxMatch = [#, ef, g, h]; LogProb = -4.2
# Reversed MaxMatch = [#, e, fgh]; LogProb = -3.1
#
# ```
#
# Have a look at the output, and see if the sequences with better language model scores (i.e. less negative) are generally more coherent.

# %%
from nltk.corpus import brown
import math
#words from brown corpus
brown_words = brown.words()
item=1
## convert to list
corpus=[]
##lower
for i in range(len(brown_words)):
    corpus.append(brown_words[i].lower())

def calcuPro(match):
    pro = 0
    for i in range(len(match)):
        ## add 1
        pro+=math.log((Counter(corpus)[match[i]]+1)/(len(corpus)+len(Counter(corpus))))
    return pro


for key, value in tokenized_hashtags.items():
    if tokenized_hashtags[key] != tokenized_hashtags_rev[key]:
        print("%d. %s"%(item,key))
        print("MaxMatch = %s; LogProb = %f"%(tokenized_hashtags[key],calcuPro(tokenized_hashtags[key])))
        print("Reversed MaxMatch = %s; LogProb=%f "%(tokenized_hashtags_rev[key],calcuPro(tokenized_hashtags_rev[key])))
        item=item+1
# Out:
# 1. #1stsundayofoctober
# MaxMatch = ['#', '1', 'st', 'sunday', 'ofo', 'c', 'tobe', 'r']; LogProb = -92.694051
# Reversed MaxMatch = ['#', '1', 'st', 'sunday', 'of', 'october']; LogProb=-58.693783
# 2. #1yearofalmostisneverenough
# MaxMatch = ['#', '1', 'year', 'of', 'almost', 'be', 'never', 'enough']; LogProb = -61.347527
# Reversed MaxMatch = ['#', '1', 'year', 'of', 'al', 'mo', 'ti', 'never', 'enough']; LogProb=-86.234593
# 3. #8thannualpubcrawl
# MaxMatch = ['#', '8', 'than', 'nu', 'alp', 'u', 'b', 'crawl']; LogProb = -90.104941
# Reversed MaxMatch = ['#', '8', 'th', 'annual', 'pub', 'crawl']; LogProb=-71.647599
# 4. #affsuzukicup
# MaxMatch = ['#', 'a', 'f', 'f', 'u', 'z', 'u', 'k', 'i', 'cup']; LogProb = -100.949986
# Reversed MaxMatch = ['#', 'a', 'f', 'f', 'suz', 'u', 'k', 'i', 'cup']; LogProb=-91.373840
# 5. #ahimacon14
# MaxMatch = ['#', 'ah', 'ima', 'con', '1', '4']; LogProb = -67.225026
# Reversed MaxMatch = ['#', 'a', 'hi', 'macon', '1', '4']; LogProb=-58.832879
# 6. #alliswell
# MaxMatch = ['#', 'all', 'be', 'well']; LogProb = -32.460037
# Reversed MaxMatch = ['#', 'al', 'li', 'swell']; LogProb=-50.690313
# 7. #allwedoiscurls
# MaxMatch = ['#', 'all', 'wed', 'o', 'be', 'curl']; LogProb = -61.781072
# Reversed MaxMatch = ['#', 'all', 'w', 'edo', 'be', 'curl']; LogProb=-64.383761
# 8. #anferneehardaway
# MaxMatch = ['#', 'an', 'fern', 'e', 'eh', 'ar', 'daw', 'ay']; LogProb = -97.224650
# Reversed MaxMatch = ['#', 'an', 'f', 'er', 'nee', 'hard', 'away']; LogProb=-74.772824
# 9. #ariona
# MaxMatch = ['#', 'arion', 'a']; LogProb = -31.969153
# Reversed MaxMatch = ['#', 'ar', 'i', 'ona']; LogProb=-47.478191
# 10. #arte
# MaxMatch = ['#', 'art', 'e']; LogProb = -32.964982
# Reversed MaxMatch = ['#', 'ar', 'te']; LogProb=-42.020888
# 11. #askherforfback
# MaxMatch = ['#', 'ask', 'her', 'for', 'f', 'back']; LogProb = -51.520229
# Reversed MaxMatch = ['#', 'ask', 'her', 'f', 'orf', 'back']; LogProb=-60.678223
# 12. #askolly
# MaxMatch = ['#', 'ask', 'o', 'l', 'ly']; LogProb = -59.045951
# Reversed MaxMatch = ['#', 'a', 'kol', 'ly']; LogProb=-45.976116
# 13. #asksteven
# MaxMatch = ['#', 'ask', 'te', 'v', 'en']; LogProb = -59.763356
# Reversed MaxMatch = ['#', 'ask', 'steven']; LogProb=-37.161076
# 14. #bedimages
# MaxMatch = ['#', 'bedim', 'age']; LogProb = -36.591543
# Reversed MaxMatch = ['#', 'bed', 'image']; LogProb=-32.381366
# 15. #beringmy
# MaxMatch = ['#', 'beri', 'n', 'g', 'my']; LogProb = -56.353410
# Reversed MaxMatch = ['#', 'be', 'ring', 'my']; LogProb=-36.211411
# 16. #bettybooppose
# MaxMatch = ['#', 'betty', 'boo', 'p', 'pose']; LogProb = -61.126660
# Reversed MaxMatch = ['#', 'betty', 'bo', 'oppose']; LogProb=-51.175821
# 17. #blackhat
# MaxMatch = ['#', 'black', 'hat']; LogProb = -32.659717
# Reversed MaxMatch = ['#', 'b', 'lac', 'khat']; LogProb=-51.364412
# 18. #blessedmorethanicanimagine
# MaxMatch = ['#', 'bless', 'more', 'than', 'i', 'can', 'imagine']; LogProb = -60.394943
# Reversed MaxMatch = ['#', 'bless', 'more', 'th', 'ani', 'can', 'imagine']; LogProb=-75.336520
# 19. #blessedsunday
# MaxMatch = ['#', 'bless', 'un', 'day']; LogProb = -44.552420
# Reversed MaxMatch = ['#', 'bless', 'sunday']; LogProb=-35.093331
# 20. #blogtourambiente
# MaxMatch = ['#', 'blo', 'g', 'tour', 'ambient', 'e']; LogProb = -73.710802
# Reversed MaxMatch = ['#', 'b', 'log', 'tou', 'ram', 'bien', 'te']; LogProb=-89.108634
# 21. #booyaa
# MaxMatch = ['#', 'boo', 'ya', 'a']; LogProb = -43.673531
# Reversed MaxMatch = ['#', 'boo', 'y', 'aa']; LogProb=-52.849797
# 22. #bradersisterhood
# MaxMatch = ['#', 'brad', 'er', 'ist', 'er', 'hood']; LogProb = -80.576041
# Reversed MaxMatch = ['#', 'brad', 'er', 'sisterhood']; LogProb=-55.334704
# 23. #bringithomemy
# MaxMatch = ['#', 'bring', 'it', 'home', 'my']; LogProb = -42.396940
# Reversed MaxMatch = ['#', 'brin', 'git', 'home', 'my']; LogProb=-54.934472
# 24. #brooksengland
# MaxMatch = ['#', 'brook', 'en', 'gland']; LogProb = -50.259530
# Reversed MaxMatch = ['#', 'brook', 'sen', 'gland']; LogProb=-52.338972
# 25. #burgers
# MaxMatch = ['#', 'burg', 'er']; LogProb = -42.020888
# Reversed MaxMatch = ['#', 'bur', 'gers']; LogProb=-42.020888
# 26. #butitsalsokindofaphone
# MaxMatch = ['#', 'but', 'it', 'also', 'kind', 'of', 'a', 'phone']; LogProb = -57.305820
# Reversed MaxMatch = ['#', 'bu', 'tit', 'also', 'kin', 'do', 'fa', 'phone']; LogProb=-92.756166
# 27. #cbcolympics
# MaxMatch = ['#', 'c', 'b', 'coly', 'm', 'pic']; LogProb = -71.741103
# Reversed MaxMatch = ['#', 'c', 'b', 'col', 'ym', 'pic']; LogProb=-74.574317
# 28. #cdnpoli
# MaxMatch = ['#', 'c', 'd', 'n', 'pol', 'i']; LogProb = -63.092708
# Reversed MaxMatch = ['#', 'c', 'd', 'n', 'po', 'li']; LogProb=-70.949221
# 29. #ciosummit
# MaxMatch = ['#', 'c', 'io', 'um', 'mi', 't']; LogProb = -71.192167
# Reversed MaxMatch = ['#', 'c', 'io', 'summit']; LogProb=-47.965734
# 30. #cleansidewalk
# MaxMatch = ['#', 'clean', 'ide', 'walk']; LogProb = -47.164235
# Reversed MaxMatch = ['#', 'clean', 'sidewalk']; LogProb=-34.681351
# 31. #coffeespoonart
# MaxMatch = ['#', 'coffee', 'poon', 'art']; LogProb = -46.316069
# Reversed MaxMatch = ['#', 'coffee', 'spoon', 'art']; LogProb=-44.370159
# 32. #cornell
# MaxMatch = ['#', 'cornel', 'l']; LogProb = -39.187675
# Reversed MaxMatch = ['#', 'cor', 'nell']; LogProb=-41.327741
# 33. #cumannanya
# MaxMatch = ['#', 'cum', 'anna', 'n', 'ya']; LogProb = -62.682373
# Reversed MaxMatch = ['#', 'c', 'u', 'mannan', 'ya']; LogProb=-60.982298
# 34. #datingsiteforyou
# MaxMatch = ['#', 'date', 'it', 'e', 'for', 'you']; LogProb = -49.350024
# Reversed MaxMatch = ['#', 'date', 'site', 'for', 'you']; LogProb=-43.960311
# 35. #difd
# MaxMatch = ['#', 'di', 'f', 'd']; LogProb = -45.349613
# Reversed MaxMatch = ['#', 'd', 'if', 'd']; LogProb=-40.468442
# 36. #endomondo
# MaxMatch = ['#', 'end', 'om', 'on', 'do']; LogProb = -47.984368
# Reversed MaxMatch = ['#', 'en', 'do', 'mon', 'do']; LogProb=-52.825872
# 37. #excitables
# MaxMatch = ['#', 'excitable', 's']; LogProb = -38.885394
# Reversed MaxMatch = ['#', 'ex', 'c', 'i', 'table']; LogProb=-50.289215
# 38. #flambees
# MaxMatch = ['#', 'flamb', 'e', 'e']; LogProb = -48.600707
# Reversed MaxMatch = ['#', 'flam', 'be']; LogProb=-33.260279
# 39. #focusateneo
# MaxMatch = ['#', 'focus', 'aten', 'e', 'o']; LogProb = -59.311833
# Reversed MaxMatch = ['#', 'fo', 'c', 'u', 'sate', 'neo']; LogProb=-76.598698
# 40. #foodporn
# MaxMatch = ['#', 'food', 'po', 'r', 'n']; LogProb = -57.017331
# Reversed MaxMatch = ['#', 'food', 'p', 'or', 'n']; LogProb=-48.685730
# 41. #fotografías
# MaxMatch = ['#', 'fot', 'og', 'ra', 'f', 'í', 'a']; LogProb = -83.692939
# Reversed MaxMatch = ['#', 'f', 'oto', 'gra', 'f', 'í', 'a']; LogProb=-80.775169
# 42. #fotorus
# MaxMatch = ['#', 'fot', 'or', 'u']; LogProb = -45.044289
# Reversed MaxMatch = ['#', 'fo', 'torus']; LogProb=-42.020888
# 43. #getfreetattooaviciipasses
# MaxMatch = ['#', 'get', 'freet', 'at', 'too', 'a', 'vic', 'i', 'i', 'pass']; LogProb = -84.872678
# Reversed MaxMatch = ['#', 'get', 'free', 'tattoo', 'a', 'vic', 'i', 'i', 'pass']; LogProb=-80.621607
# 44. #goingout
# MaxMatch = ['#', 'go', 'out']; LogProb = -27.931202
# Reversed MaxMatch = ['#', 'go', 'in', 'gout']; LogProb=-38.520048
# 45. #google
# MaxMatch = ['#', 'goo', 'g', 'l', 'e']; LogProb = -60.654815
# Reversed MaxMatch = ['#', 'go', 'ogle']; LogProb=-35.579942
# 46. #grammyfans
# MaxMatch = ['#', 'gram', 'my', 'fan']; LogProb = -43.500888
# Reversed MaxMatch = ['#', 'g', 'rammy', 'fan']; LogProb=-50.250199
# 47. #grandmarnier
# MaxMatch = ['#', 'grandma', 'r', 'ni', 'er']; LogProb = -63.732195
# Reversed MaxMatch = ['#', 'grand', 'm', 'arni', 'er']; LogProb=-63.309780
# 48. #happybirthdaysandarapark
# MaxMatch = ['#', 'happy', 'birthday', 'anda', 'rap', 'ark']; LogProb = -75.403606
# Reversed MaxMatch = ['#', 'happy', 'birthday', 'sand', 'ara', 'park']; LogProb=-68.581045
# 49. #harimaumalaya
# MaxMatch = ['#', 'ha', 'rima', 'um', 'ala', 'ya']; LogProb = -79.724289
# Reversed MaxMatch = ['#', 'h', 'ar', 'i', 'mau', 'mala', 'ya']; LogProb=-84.711587
# 50. #hometomama
# MaxMatch = ['#', 'home', 'toma', 'ma']; LogProb = -46.725844
# Reversed MaxMatch = ['#', 'home', 'tom', 'ama']; LogProb=-44.869546
# 51. #ididntchoosethestudentlifeitchoseme
# MaxMatch = ['#', 'id', 'id', 'n', 'tch', 'o', 'ose', 'the', 'student', 'life', 'itch', 'ose', 'me']; LogProb = -143.652063
# Reversed MaxMatch = ['#', 'i', 'didnt', 'choose', 'the', 'student', 'life', 'it', 'cho', 'seme']; LogProb=-95.897744
# 52. #imsobored
# MaxMatch = ['#', 'i', 'm', 'o', 'bore']; LogProb = -52.137228
# Reversed MaxMatch = ['#', 'i', 'm', 'so', 'bore']; LogProb=-47.839187
# 53. #imsosore
# MaxMatch = ['#', 'i', 'm', 'o', 'ore']; LogProb = -55.356103
# Reversed MaxMatch = ['#', 'i', 'm', 'so', 'sore']; LogProb=-48.660167
# 54. #innoretail
# MaxMatch = ['#', 'inn', 'ore', 'tail']; LogProb = -50.506390
# Reversed MaxMatch = ['#', 'in', 'no', 'retail']; LogProb=-35.346523
# 55. #insightmediasingapore
# MaxMatch = ['#', 'insight', 'medium', 'sing', 'a', 'pore']; LogProb = -62.371946
# Reversed MaxMatch = ['#', 'insight', 'me', 'di', 'a', 'inga', 'pore']; LogProb=-73.552441
# 56. #instagood
# MaxMatch = ['#', 'in', 'tag', 'o', 'od']; LogProb = -54.978973
# Reversed MaxMatch = ['#', 'in', 'ta', 'good']; LogProb=-39.366283
# 57. #instalook
# MaxMatch = ['#', 'in', 'tal', 'o', 'ok']; LogProb = -54.978973
# Reversed MaxMatch = ['#', 'in', 'ta', 'look']; LogProb=-40.068142
# 58. #isibaya
# MaxMatch = ['#', 'be', 'iba', 'ya']; LogProb = -45.657803
# Reversed MaxMatch = ['#', 'i', 'si', 'baya']; LogProb=-46.785044
# 59. #jordaan
# MaxMatch = ['#', 'jo', 'r', 'da', 'an']; LogProb = -53.425645
# Reversed MaxMatch = ['#', 'j', 'or', 'da', 'an']; LogProb=-48.744702
# 60. #jrsurfboards
# MaxMatch = ['#', 'j', 'r', 'urf', 'board']; LogProb = -58.944703
# Reversed MaxMatch = ['#', 'j', 'r', 'surfboard']; LogProb=-50.418379
# 61. #ladygaga
# MaxMatch = ['#', 'lady', 'gag', 'a']; LogProb = -39.972229
# Reversed MaxMatch = ['#', 'lady', 'g', 'aga']; LogProb=-48.800189
# 62. #laundryservice
# MaxMatch = ['#', 'laundry', 'er', 'vice']; LogProb = -50.498422
# Reversed MaxMatch = ['#', 'laundry', 'service']; LogProb=-34.473387
# 63. #learningcommunties
# MaxMatch = ['#', 'learn', 'c', 'om', 'munt', 'y']; LogProb = -73.003345
# Reversed MaxMatch = ['#', 'learn', 'c', 'om', 'm', 'untie']; LogProb=-70.863279
# 64. #lebedeintennis
# MaxMatch = ['#', 'l', 'e', 'bed', 'e', 'in', 'tennis']; LogProb = -70.195518
# Reversed MaxMatch = ['#', 'l', 'e', 'be', 'de', 'in', 'tennis']; LogProb=-65.188326
# 65. #letmesleep
# MaxMatch = ['#', 'let', 'me', 'leep']; LogProb = -42.999645
# Reversed MaxMatch = ['#', 'let', 'me', 'sleep']; LogProb=-38.809990
# 66. #loadsoffun
# MaxMatch = ['#', 'load', 'off', 'un']; LogProb = -43.098684
# Reversed MaxMatch = ['#', 'load', 'of', 'fun']; LogProb=-37.889866
# 67. #longranger
# MaxMatch = ['#', 'long', 'ranger']; LogProb = -34.298211
# Reversed MaxMatch = ['#', 'l', 'on', 'granger']; LogProb=-44.378526
# 68. #magazinesandtvscreens
# MaxMatch = ['#', 'magazine', 'and', 't', 'v', 'creen', 's']; LogProb = -73.265449
# Reversed MaxMatch = ['#', 'magazine', 'sand', 't', 'v', 'screen']; LogProb=-65.404868
# 69. #makeupfree
# MaxMatch = ['#', 'make', 'up', 'free']; LogProb = -36.243966
# Reversed MaxMatch = ['#', 'ma', 'keup', 'free']; LogProb=-47.471437
# 70. #mamajeanneandme
# MaxMatch = ['#', 'mam', 'a', 'jeanne', 'and', 'me']; LogProb = -56.645075
# Reversed MaxMatch = ['#', 'm', 'ama', 'jeanne', 'and', 'me']; LogProb=-63.170449
# 71. #meetup
# MaxMatch = ['#', 'meet', 'up']; LogProb = -29.465392
# Reversed MaxMatch = ['#', 'me', 'e', 'tup']; LogProb=-45.239316
# 72. #melbourne
# MaxMatch = ['#', 'mel', 'bourn', 'e']; LogProb = -49.423907
# Reversed MaxMatch = ['#', 'm', 'elb', 'our', 'ne']; LogProb=-58.122395
# 73. #mtlnewtech
# MaxMatch = ['#', 'm', 't', 'l', 'newt', 'e', 'c', 'h']; LogProb = -88.139695
# Reversed MaxMatch = ['#', 'm', 't', 'l', 'new', 'tech']; LogProb=-64.421407
# 74. #myfriendsarebetterthanyours
# MaxMatch = ['#', 'my', 'friend', 'be', 'better', 'than', 'yours']; LogProb = -60.428756
# Reversed MaxMatch = ['#', 'my', 'friend', 'sare', 'better', 'than', 'yours']; LogProb=-69.189366
# 75. #nced
# MaxMatch = ['#', 'n', 'ce', 'd']; LogProb = -48.432464
# Reversed MaxMatch = ['#', 'n', 'c', 'ed']; LogProb=-44.921211
# 76. #nevergetsold
# MaxMatch = ['#', 'never', 'get', 'old']; LogProb = -36.364293
# Reversed MaxMatch = ['#', 'never', 'get', 'sell']; LogProb=-39.121889
# 77. #nickryrie
# MaxMatch = ['#', 'nick', 'r', 'yr', 'ie']; LogProb = -63.113156
# Reversed MaxMatch = ['#', 'nick', 'r', 'y', 'rie']; LogProb=-61.321396
# 78. #oilandgas
# MaxMatch = ['#', 'oil', 'and', 'gas']; LogProb = -36.588329
# Reversed MaxMatch = ['#', 'o', 'i', 'land', 'gas']; LogProb=-48.195075
# 79. #olah
# MaxMatch = ['#', 'o', 'la', 'h']; LogProb = -45.583669
# Reversed MaxMatch = ['#', 'o', 'l', 'ah']; LogProb=-46.763307
# 80. #openspace
# MaxMatch = ['#', 'open', 'pace']; LogProb = -32.471508
# Reversed MaxMatch = ['#', 'open', 'space']; LogProb=-31.035341
# 81. #palacefansinthemorning
# MaxMatch = ['#', 'palace', 'fan', 'in', 'them', 'or', 'ning']; LogProb = -65.638577
# Reversed MaxMatch = ['#', 'palace', 'fan', 'sin', 'the', 'morning']; LogProb=-56.932355
# 82. #pechanga
# MaxMatch = ['#', 'pech', 'an', 'ga']; LogProb = -47.107596
# Reversed MaxMatch = ['#', 'p', 'e', 'changa']; LogProb=-47.970474
# 83. #peperoni
# MaxMatch = ['#', 'pep', 'er', 'on', 'i']; LogProb = -52.669042
# Reversed MaxMatch = ['#', 'pep', 'e', 'ro', 'ni']; LogProb=-66.321242
# 84. #photoby
# MaxMatch = ['#', 'photo', 'by']; LogProb = -31.652347
# Reversed MaxMatch = ['#', 'pho', 'toby']; LogProb=-42.020888
# 85. #pmattheashes
# MaxMatch = ['#', 'p', 'matt', 'he', 'ash']; LogProb = -52.655616
# Reversed MaxMatch = ['#', 'p', 'mat', 'the', 'ash']; LogProb=-50.258492
# 86. #potd
# MaxMatch = ['#', 'pot', 'd']; LogProb = -34.721767
# Reversed MaxMatch = ['#', 'po', 'td']; LogProb=-41.327741
# 87. #rainorshine
# MaxMatch = ['#', 'rain', 'or', 'hin', 'e']; LogProb = -53.714057
# Reversed MaxMatch = ['#', 'r', 'ai', 'nor', 'shine']; LogProb=-58.608231
# 88. #reachingyougpeople
# MaxMatch = ['#', 'reach', 'you', 'g', 'people']; LogProb = -47.697550
# Reversed MaxMatch = ['#', 'reach', 'yo', 'ug', 'people']; LogProb=-58.628494
# 89. #ritenow
# MaxMatch = ['#', 'rite', 'now']; LogProb = -32.642072
# Reversed MaxMatch = ['#', 'rit', 'enow']; LogProb=-42.020888
# 90. #samsung
# MaxMatch = ['#', 'sam', 'un', 'g']; LogProb = -46.173554
# Reversed MaxMatch = ['#', 'sam', 'sing']; LogProb=-34.083514
# 91. #scifigeek
# MaxMatch = ['#', 's', 'c', 'if', 'i', 'geek']; LogProb = -59.856843
# Reversed MaxMatch = ['#', 's', 'c', 'i', 'fi', 'geek']; LogProb=-67.552601
# 92. #seniorbabysenior
# MaxMatch = ['#', 'senior', 'baby', 'en', 'io', 'r']; LogProb = -69.907144
# Reversed MaxMatch = ['#', 'senior', 'baby', 'senior']; LogProb=-44.774020
# 93. #shopaholic
# MaxMatch = ['#', 'shop', 'aho', 'li', 'c']; LogProb = -61.071910
# Reversed MaxMatch = ['#', 'sho', 'paho', 'li', 'c']; LogProb=-65.230793
# 94. #siberuang
# MaxMatch = ['#', 'sib', 'er', 'uang']; LogProb = -56.027851
# Reversed MaxMatch = ['#', 'si', 'ber', 'uang']; LogProb=-55.334704
# 95. #singapore
# MaxMatch = ['#', 'sing', 'a', 'pore']; LogProb = -41.322156
# Reversed MaxMatch = ['#', 's', 'inga', 'pore']; LogProb=-51.793745
# 96. #skeemsaam
# MaxMatch = ['#', 'skee', 'm', 'aam']; LogProb = -53.194638
# Reversed MaxMatch = ['#', 's', 'k', 'e', 'em', 'aam']; LogProb=-73.185377
# 97. #skullsearcher
# MaxMatch = ['#', 'skull', 'ear', 'che', 'r']; LogProb = -60.890613
# Reversed MaxMatch = ['#', 'skull', 'searcher']; LogProb=-40.634594
# 98. #socal
# MaxMatch = ['#', 'soc', 'al']; LogProb = -38.762792
# Reversed MaxMatch = ['#', 'so', 'cal']; LogProb=-33.733863
# 99. #southampton
# MaxMatch = ['#', 'south', 'be', 'p', 'ton']; LogProb = -48.806544
# Reversed MaxMatch = ['#', 's', 'out', 'ham', 'p', 'ton']; LogProb=-63.278948
# 100. #startupfest
# MaxMatch = ['#', 'start', 'up', 'fest']; LogProb = -43.439565
# Reversed MaxMatch = ['#', 'star', 'tup', 'fest']; LogProb=-52.769755
# 101. #startuphub
# MaxMatch = ['#', 'start', 'up', 'hub']; LogProb = -40.954658
# Reversed MaxMatch = ['#', 'star', 'tup', 'hub']; LogProb=-50.284848
# 102. #statoftheday
# MaxMatch = ['#', 'st', 'at', 'oft', 'he', 'day']; LogProb = -59.061507
# Reversed MaxMatch = ['#', 's', 'tat', 'of', 'the', 'day']; LogProb=-52.020815
# 103. #strictlyus
# MaxMatch = ['#', 'strictly', 'u']; LogProb = -35.855471
# Reversed MaxMatch = ['#', 'strict', 'l', 'yus']; LogProb=-50.709731
# 104. #surfshop
# MaxMatch = ['#', 'surf', 'hop']; LogProb = -40.229129
# Reversed MaxMatch = ['#', 'surf', 'shop']; LogProb=-37.168858
# 105. #swedumtl
# MaxMatch = ['#', 's', 'wed', 'um', 't', 'l']; LogProb = -71.008310
# Reversed MaxMatch = ['#', 's', 'we', 'dum', 't', 'l']; LogProb=-65.832914
# 106. #takeabreak
# MaxMatch = ['#', 'take', 'ab', 'reak']; LogProb = -48.226460
# Reversed MaxMatch = ['#', 'ta', 'kea', 'break']; LogProb=-51.539215
# 107. #thankyoulord
# MaxMatch = ['#', 'thank', 'youl', 'or', 'd']; LogProb = -54.147565
# Reversed MaxMatch = ['#', 'thank', 'you', 'lord']; LogProb=-39.775908
# 108. #thankyoupatients
# MaxMatch = ['#', 'thank', 'youp', 'ati', 'en', 't']; LogProb = -73.994709
# Reversed MaxMatch = ['#', 'thank', 'you', 'patient']; LogProb=-39.853295
# 109. #thenext5goldenyears
# MaxMatch = ['#', 'then', 'ex', 't', '5', 'golden', 'year']; LogProb = -70.148087
# Reversed MaxMatch = ['#', 'the', 'next', '5', 'golden', 'year']; LogProb=-51.692272
# 110. #thevoiceau
# MaxMatch = ['#', 'the', 'voice', 'a', 'u']; LogProb = -40.763221
# Reversed MaxMatch = ['#', 'the', 'v', 'o', 'i', 'c', 'ea', 'u']; LogProb=-78.279072
# 111. #thewalkingdead
# MaxMatch = ['#', 'thew', 'alk', 'ing', 'dead']; LogProb = -64.870028
# Reversed MaxMatch = ['#', 'the', 'walk', 'dead']; LogProb=-35.092094
# 112. #toronto
# MaxMatch = ['#', 'toro', 'n', 'to']; LogProb = -42.192341
# Reversed MaxMatch = ['#', 'tor', 'onto']; LogProb=-37.910015
# 113. #txlege
# MaxMatch = ['#', 't', 'x', 'leg', 'e']; LogProb = -55.114407
# Reversed MaxMatch = ['#', 't', 'x', 'l', 'e', 'ge']; LogProb=-69.267082
# 114. #uniexamonasaturday
# MaxMatch = ['#', 'unie', 'x', 'be', 'ona', 'saturday']; LogProb = -68.289071
# Reversed MaxMatch = ['#', 'u', 'ni', 'ex', 'a', 'mona', 'saturday']; LogProb=-80.039827
# 115. #uptonogood
# MaxMatch = ['#', 'up', 'ton', 'og', 'o', 'od']; LogProb = -70.562022
# Reversed MaxMatch = ['#', 'up', 'to', 'no', 'good']; LogProb=-37.956120
# 116. #usydhereicome
# MaxMatch = ['#', 'u', 'y', 'd', 'here', 'i', 'come']; LogProb = -68.067725
# Reversed MaxMatch = ['#', 'u', 'syd', 'here', 'i', 'come']; LogProb=-59.784348
# 117. #usydoweek
# MaxMatch = ['#', 'u', 'y', 'dow', 'e', 'e', 'k']; LogProb = -82.183446
# Reversed MaxMatch = ['#', 'u', 'y', 'do', 'week']; LogProb=-52.765420
# 118. #vegan
# MaxMatch = ['#', 'vega', 'n']; LogProb = -38.357327
# Reversed MaxMatch = ['#', 'v', 'e', 'gin']; LogProb=-45.804021
# 119. #veganfood
# MaxMatch = ['#', 'vega', 'n', 'food']; LogProb = -47.367077
# Reversed MaxMatch = ['#', 'v', 'e', 'gin', 'food']; LogProb=-54.813771
# 120. #vscocam
# MaxMatch = ['#', 'v', 'coca', 'm']; LogProb = -49.862433
# Reversed MaxMatch = ['#', 'v', 'c', 'o', 'cam']; LogProb=-57.909604
# 121. #weare90s
# MaxMatch = ['#', 'wear', 'e', '9', '0', 's']; LogProb = -66.330563
# Reversed MaxMatch = ['#', 'we', 'be', '9', '0', 's']; LogProb=-56.983597
# 122. #wearesocial
# MaxMatch = ['#', 'wear', 'o', 'c', 'i', 'al']; LogProb = -60.550643
# Reversed MaxMatch = ['#', 'we', 'be', 'social']; LogProb=-33.440996
# 123. #wok
# MaxMatch = ['#', 'wo', 'k']; LogProb = -39.622993
# Reversed MaxMatch = ['#', 'w', 'ok']; LogProb=-38.437369
# 124. #yiamas
# MaxMatch = ['#', 'y', 'i', 'ama', 's']; LogProb = -55.864753
# Reversed MaxMatch = ['#', 'y', 'i', 'a', 'ma']; LogProb=-46.645927

# %% [markdown]
# # Text Classification (4 marks)

# %% [markdown]
# ### Question 5 (1.0 mark)
#
# **Instructions**: Here we are interested to do text classification, to predict the country of origin of a given tweet. The task here is to create training, development and test partitions from the preprocessed data (`x_processed`) and convert the bag-of-words representation into feature vectors.
#
# **Task**: Create training, development and test partitions with a 70%/15%/15% ratio. Remember to preserve the ratio of the classes for all your partitions. That is, say we have only 2 classes and 70% of instances are labelled class A and 30% of instances are labelled class B, then the instances in training, development and test partitions should also preserve this 7:3 ratio. You may use sklearn's builtin functions for doing data partitioning.
#
# Next, turn the bag-of-words dictionary of each tweet into a feature vector. You may also use sklearn's builtin functions for doing this (but if you don't want to use sklearn that's fine).
#
# You should produce 6 objects: `x_train`, `x_dev`, `x_test` which contain the input feature vectors, and `y_train`, `y_dev` and `y_test` which contain the labels.

# %%
import sklearn
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.feature_extraction.text import  TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

x_train, x_dev, x_test = None, None, None
y_train, y_dev, y_test = None, None, None

x_train,x_test,y_train,y_test = train_test_split(x_processed, y_processed, test_size = 0.3,random_state = 10000, stratify=y_processed)


x_dev,x_test,y_dev,y_test = train_test_split(x_test, y_test, test_size = 0.5,random_state = 10000, stratify=y_test)



vec = DictVectorizer( )   
x_train=vec.fit_transform(x_train)
x_dev=vec.transform(x_dev)
x_test=vec.transform(x_test)


print(x_train.shape)
print(x_test.shape)
print(x_dev.shape)
# Out:
# (660, 3284)
# (142, 3284)
# (141, 3284)

# %% [markdown]
# ### Question 6 (1.0 mark)
#
# **Instructions**: Now, let's build some classifiers. Here, we'll be comparing Naive Bayes and Logistic Regression. For each, you need to first find a good value for their main regularisation hyper-parameters, which you should identify using the scikit-learn docs or other resources. Use the development set you created for this tuning process; do **not** use cross-validation in the training set, or involve the test set in any way. You don't need to show all your work, but you do need to print out the **accuracy** with enough different settings to strongly suggest you have found an optimal or near-optimal choice. We should not need to look at your code to interpret the output.
#
# **Task**: Implement two text classifiers: Naive Bayes and Logistic Regression. Tune the hyper-parameters of these classifiers and print the task performance (accuracy) for different hyper-parameter settings.

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import StratifiedKFold 
from sklearn.model_selection import GridSearchCV



##Naive Bayes  tunning
print("Naive Bayes  tunning")
best_score = 0
outcomes=[]
bestalpha=0.0
for i in np.arange(0.1, 10, 0.1):
    predictions = []
    clf = MultinomialNB(alpha= i ,class_prior=None,fit_prior=True)
    clf.fit(x_train, y_train)
    predictions = clf.predict(x_dev)
    MultinomialNB_acc=accuracy_score(predictions ,y_dev)    
    outcomes.append("alpha=%f acc=%f"%(i,MultinomialNB_acc))
    if MultinomialNB_acc > best_score:
        best_score = MultinomialNB_acc
        best_parameters = {'alpha':i}
        bestalpha=i
print("Naive Bayes Best acc:{:.3f}".format(best_score))
print("Naive Bayes Best_parameters:%s"%best_parameters)
print("")
print(outcomes[:30])


##Logistic Regression tunning
print("")
print("Logistic Regression tunning")
best_score = 0
outcomes=[]
solvers = ['newton-cg', 'lbfgs', 'liblinear']
for i in np.arange(0.1, 3,0.1):
    for j in solvers:
        lr = LogisticRegression(max_iter=5000,C=i,solver=j)
        lr.fit(x_train, y_train)
        pred=lr.predict(x_dev)
        LogisticRegression_acc=accuracy_score(pred ,y_dev)
        outcomes.append("Cvalue=%f solvers=%s acc=%f"%(i,j,LogisticRegression_acc))
        if LogisticRegression_acc > best_score:
            best_score = LogisticRegression_acc
            best_parameters = {'Cvalue':i,'solvers':j,'penalty':12}
            bestCvalue=i
            bestsolvers=j
print("LogisticRegression_acc Best acc:{:.3f}".format(best_score))
print("LogisticRegression_acc Best_parameters:%s"%best_parameters)
print("")
print(outcomes[:30])
# Out:
# Naive Bayes  tunning
# Naive Bayes Best acc:0.340
# Naive Bayes Best_parameters:{'alpha': 9.6}
#
# ['alpha=0.100000 acc=0.319149', 'alpha=0.200000 acc=0.319149', 'alpha=0.300000 acc=0.319149', 'alpha=0.400000 acc=0.319149', 'alpha=0.500000 acc=0.326241', 'alpha=0.600000 acc=0.312057', 'alpha=0.700000 acc=0.312057', 'alpha=0.800000 acc=0.312057', 'alpha=0.900000 acc=0.312057', 'alpha=1.000000 acc=0.319149', 'alpha=1.100000 acc=0.319149', 'alpha=1.200000 acc=0.319149', 'alpha=1.300000 acc=0.319149', 'alpha=1.400000 acc=0.326241', 'alpha=1.500000 acc=0.333333', 'alpha=1.600000 acc=0.333333', 'alpha=1.700000 acc=0.333333', 'alpha=1.800000 acc=0.333333', 'alpha=1.900000 acc=0.333333', 'alpha=2.000000 acc=0.326241', 'alpha=2.100000 acc=0.326241', 'alpha=2.200000 acc=0.326241', 'alpha=2.300000 acc=0.326241', 'alpha=2.400000 acc=0.326241', 'alpha=2.500000 acc=0.326241', 'alpha=2.600000 acc=0.326241', 'alpha=2.700000 acc=0.326241', 'alpha=2.800000 acc=0.326241', 'alpha=2.900000 acc=0.326241', 'alpha=3.000000 acc=0.326241']
#
# Logistic Regression tunning
# LogisticRegression_acc Best acc:0.326
# LogisticRegression_acc Best_parameters:{'Cvalue': 0.1, 'solvers': 'newton-cg', 'penalty': 12}
#
# ['Cvalue=0.100000 solvers=newton-cg acc=0.326241', 'Cvalue=0.100000 solvers=lbfgs acc=0.326241', 'Cvalue=0.100000 solvers=liblinear acc=0.326241', 'Cvalue=0.200000 solvers=newton-cg acc=0.297872', 'Cvalue=0.200000 solvers=lbfgs acc=0.297872', 'Cvalue=0.200000 solvers=liblinear acc=0.304965', 'Cvalue=0.300000 solvers=newton-cg acc=0.297872', 'Cvalue=0.300000 solvers=lbfgs acc=0.297872', 'Cvalue=0.300000 solvers=liblinear acc=0.297872', 'Cvalue=0.400000 solvers=newton-cg acc=0.297872', 'Cvalue=0.400000 solvers=lbfgs acc=0.297872', 'Cvalue=0.400000 solvers=liblinear acc=0.297872', 'Cvalue=0.500000 solvers=newton-cg acc=0.304965', 'Cvalue=0.500000 solvers=lbfgs acc=0.304965', 'Cvalue=0.500000 solvers=liblinear acc=0.304965', 'Cvalue=0.600000 solvers=newton-cg acc=0.304965', 'Cvalue=0.600000 solvers=lbfgs acc=0.304965', 'Cvalue=0.600000 solvers=liblinear acc=0.304965', 'Cvalue=0.700000 solvers=newton-cg acc=0.304965', 'Cvalue=0.700000 solvers=lbfgs acc=0.304965', 'Cvalue=0.700000 solvers=liblinear acc=0.297872', 'Cvalue=0.800000 solvers=newton-cg acc=0.304965', 'Cvalue=0.800000 solvers=lbfgs acc=0.304965', 'Cvalue=0.800000 solvers=liblinear acc=0.290780', 'Cvalue=0.900000 solvers=newton-cg acc=0.312057', 'Cvalue=0.900000 solvers=lbfgs acc=0.312057', 'Cvalue=0.900000 solvers=liblinear acc=0.290780', 'Cvalue=1.000000 solvers=newton-cg acc=0.304965', 'Cvalue=1.000000 solvers=lbfgs acc=0.304965', 'Cvalue=1.000000 solvers=liblinear acc=0.304965']

# %%
# ##CV grid search
# model = LogisticRegression()
# solvers = ['newton-cg', 'lbfgs', 'liblinear']
# penalty = ['l2']
# c_values = [100, 10, 0.1, 0.01]
# # define grid search
# grid = dict(solver=solvers,penalty=penalty,C=c_values)
# grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, scoring='accuracy',error_score=0)
# grid_result = grid_search.fit(x_train, y_train)
# print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

# %% [markdown]
# ### Question 7 (1.0 mark)
#
# **Instructions**: Using the best settings you have found, compare the two classifiers based on performance in the test set. Print out both **accuracy** and **macro-averaged F-score** for each classifier. Be sure to label your output. You may use sklearn's inbuilt functions.
#
# **Task**: Compute test performance in terms of accuracy and macro-averaged F-score for both Naive Bayes and Logistic Regression, using their optimal hyper-parameter settings based on their development performance.

# %%
from sklearn.metrics import accuracy_score, f1_score


predictions = []
clf = MultinomialNB(alpha= bestalpha ,class_prior=None,fit_prior=True)
clf.fit(x_train, y_train)
predictions = clf.predict(x_test)
MultinomialNB_acc=accuracy_score(predictions ,y_test)  
NB_f1=f1_score(y_test,predictions, average='macro')

pred=[]
lr = LogisticRegression(max_iter=5000,C=bestCvalue,solver=bestsolvers)
lr.fit(x_train, y_train)
pred=lr.predict(x_test)
LogisticRegression_acc=accuracy_score(pred ,y_test)
lr_f1=f1_score(y_test,pred, average='macro')




print(f"NB_acc\t\tAccuracy: {round(MultinomialNB_acc, 3)}\tMacro F1: {round(NB_f1, 3)}")
print(f"lr_acc\t\tAccuracy: {round(LogisticRegression_acc, 3)}\tMacro F1: {round(lr_f1, 3)}")
# Out:
# NB_acc		Accuracy: 0.211	Macro F1: 0.209
# lr_acc		Accuracy: 0.232	Macro F1: 0.216

# %% [markdown]
# ### Question 8 (1.0 mark)
#
# **Instructions**: Print the most important features and their weights for each class for the two classifiers.
#
#
# **Task**: For each of the classifiers (Logistic Regression and Naive Bayes) you've built in the previous question, print out the top-20 features (words) with the highest weight for each class (countries).
#
# An example output:
# ```
# Classifier = Logistic Regression
#
# Country = au
# aaa (0.999) bbb (0.888) ccc (0.777) ...
#
# Country = ca
# aaa (0.999) bbb (0.888) ccc (0.777) ...
#
# Classifier = Naive Bayes
#
# Country = au
# aaa (-1.0) bbb (-2.0) ccc (-3.0) ...
#
# Country = ca
# aaa (-1.0) bbb (-2.0) ccc (-3.0) ...
# ```
#
# Have a look at the output, and see if you notice any trend/pattern in the words for each country.

# %%
##define names, assign values
label=sorted(set(y_train))
names = locals()
for i in range(10):
    names[str(label[i])+'_class_prob_sorted'  ] = clf.feature_log_prob_[i, :].argsort()[::-1]
    names[str(label[i])+'_class_prob_sorted_lr'  ] =lr.coef_[i, :].argsort()[::-1]
##print all Countries
for i in range(10):
    print("")
    print("Country=%s"%label[i])
    print("Naive Bayes")
    for j in range(20):
        print("%s:(%d) "%(np.take(vec.get_feature_names_out(),  names[str(label[i])+'_class_prob_sorted' ][:20])[j],clf.feature_log_prob_[i, :][j]),end='')
    print("")
    print("Logistic Regression")
    for j in range(20):
        print("%s:(%f) "%(np.take(vec.get_feature_names_out(), names[str(label[i])+'_class_prob_sorted_lr'  ] [:20])[j],lr.coef_[i, :][j]),end='')
    print("")
# Out:
# Country=au
# Naive Bayes
# great:(-8) i'm:(-8) keep:(-8) melbourne:(-8) get:(-8) love:(-8) victoria:(-8) australia:(-8) pretty:(-8) cry:(-8) please:(-8) today:(-8) direction:(-8) win:(-8) people:(-8) say:(-8) #sunrise:(-8) even:(-8) would:(-8) finished:(-8)
# Logistic Regression
# great:(0.071869) melbourne:(-0.010507) australia:(-0.007339) victoria:(-0.010377) keep:(-0.010106) australian:(0.075234) #sunrise:(-0.009287) finished:(-0.010511) name:(-0.010511) cry:(-0.009393) lovely:(0.078775) little:(0.081692) #mtvhottest:(-0.007885) sledging:(-0.007885) vca:(-0.010059) big:(-0.008966) anything:(-0.009650) end:(-0.008966) another:(0.077724) friends:(0.077724)
#
# Country=ca
# Naive Bayes
# one:(-8) maybe:(-8) i'm:(-8) first:(-8) great:(-8) today:(-8) thing:(-8) got:(-8) get:(-8) school:(-8) right:(-8) like:(-8) next:(-8) really:(-8) live:(-8) want:(-8) need:(-8) w:(-8) know:(-8) douglas:(-8)
# Logistic Regression
# maybe:(-0.011786) thing:(-0.008470) first:(-0.007469) one:(-0.009788) today:(-0.009558) great:(-0.009774) really:(-0.010268) next:(-0.009910) happen:(-0.009910) right:(0.083210) school:(-0.009061) movies:(-0.010957) awesome:(-0.008009) side:(-0.008009) #devacurl:(-0.009499) salon:(0.076796) found:(-0.007976) learning:(0.076796) bed:(-0.008767) uncle:(-0.008767)
#
# Country=de
# Naive Bayes
# posted:(-8) love:(-8) photo:(-8) i'm:(-8) factory:(-8) remstal:(-8) enough:(-8) week:(-8) please:(-8) painting:(-8) im:(-8) photodesign:(-8) kernen:(-8) never:(-8) almost:(-8) come:(-8) germany:(-8) mkmedi:(-8) #rosegold:(-8) night:(-8)
# Logistic Regression
# posted:(-0.004740) love:(0.084694) photo:(-0.004054) factory:(-0.005184) photodesign:(0.088039) mkmedi:(-0.005078) remstal:(0.087202) kernen:(-0.005225) #rosegold:(-0.005225) painting:(-0.004888) enough:(-0.004891) almost:(-0.004724) germany:(-0.004277) never:(-0.004277) night:(-0.005071) week:(-0.004907) im:(-0.006511) come:(-0.004907) please:(-0.005733) @fabiomarabini:(-0.005733)
#
# Country=gb
# Naive Bayes
# got:(-8) yeah:(-8) x:(-8) beat:(-8) well:(-8) i'm:(-8) hope:(-8) sure:(-8) always:(-8) next:(-8) new:(-8) fear:(-8) back:(-8) know:(-8) i've:(-8) plz:(-8) time:(-8) right:(-8) beautiful:(-8) wbu:(-8)
# Logistic Regression
# yeah:(-0.007938) x:(-0.008726) sure:(-0.008208) well:(-0.010007) got:(-0.009762) beat:(-0.008641) plz:(-0.009038) always:(-0.010134) beautiful:(-0.010134) i've:(-0.009090) next:(-0.009255) fear:(-0.008579) chelsea:(-0.008737) golf:(-0.008737) staines:(-0.009708) xx:(-0.011844) holly:(-0.009580) wbu:(-0.011844) @skyhelpteam:(-0.009016) right:(-0.009016)
#
# Country=id
# Naive Bayes
# pic:(-8) rt:(-8) i'm:(-8) others:(-8) cafe:(-8) coffee:(-8) wkwk:(-8) donuts:(-8) ini:(-8) overboard:(-8) @jcoindonesia:(-8) shaw:(-8) @justinbieber:(-8) right:(-8) direction:(-8) photo:(-8) j.co:(-8) way:(-8) house:(-8) one:(-8)
# Logistic Regression
# pic:(-0.006926) rt:(-0.010120) donuts:(-0.007605) coffee:(-0.010779) wkwk:(-0.010479) ini:(-0.009258) cafe:(-0.009522) others:(-0.010923) overboard:(-0.010923) sore:(-0.011485) flat:(-0.009938) vid:(-0.009235) keras:(-0.008124) kerja:(-0.008124) j.co:(-0.010442) @jcoindonesia:(-0.008646) banget:(-0.009457) ga:(-0.008646) @justinbieber:(-0.009690) bieber:(-0.009690)
#
# Country=my
# Naive Bayes
# i'm:(-8) selangor:(-8) jaya:(-8) thank:(-8) happy:(-8) birthday:(-8) w:(-8) hahaha:(-8) aku:(-8) lumpur:(-8) tu:(-8) others:(-8) haha:(-8) last:(-8) subang:(-8) petaling:(-8) ni:(-8) one:(-8) johor:(-8) kuala:(-8)
# Logistic Regression
# i'm:(-0.006924) selangor:(-0.008561) jaya:(-0.007569) thank:(0.085652) johor:(-0.009564) birthday:(-0.008358) ni:(-0.008145) kuala:(-0.009916) lumpur:(-0.009916) aku:(-0.010470) tu:(-0.009066) hahaha:(-0.009129) petaling:(0.073169) last:(0.073169) subang:(-0.009505) @poemporns:(-0.008632) kl:(-0.007560) congrats:(-0.008632) pls:(-0.008860) smpai:(-0.008860)
#
# Country=ph
# Naive Bayes
# follow:(-8) manila:(-8) i'm:(-8) others:(-8) sm:(-8) please:(-8) :d:(-8) w:(-8) lol:(-8) city:(-8) mo:(-8) back:(-8) baby:(-8) ko:(-8) metro:(-8) ng:(-8) na:(-8) ka:(-8) ako:(-8) exercise:(-8)
# Logistic Regression
# manila:(-0.008644) follow:(-0.010282) :d:(-0.012134) sm:(-0.010231) baby:(-0.009970) ng:(-0.008812) ko:(-0.009213) please:(-0.010362) na:(-0.010362) ka:(-0.009270) metro:(-0.009453) mo:(-0.010235) city:(-0.008287) others:(-0.008287) lol:(0.082706) welcome:(-0.008232) mcdonald's:(0.080167) sight:(-0.008232) hihi:(-0.009216) kg:(-0.009216)
#
# Country=sg
# Naive Bayes
# singapore:(-8) i'm:(-8) w:(-8) others:(-8) thanks:(-8) work:(-8) say:(-8) see:(-8) hotel:(-8) pic:(-8) park:(-8) resort:(-8) @khoirul_irwanqu:(-8) kau:(-8) come:(-8) fitness:(-8) nice:(-8) time:(-8) week:(-8) irwan:(-8)
# Logistic Regression
# singapore:(-0.007192) hotel:(-0.008239) w:(-0.007238) work:(-0.009385) park:(-0.009180) thanks:(-0.008091) see:(-0.009208) others:(-0.009498) fitness:(-0.009498) resort:(-0.008552) air:(-0.008701) starbucks:(-0.008176) #hungry:(-0.007211) kau:(-0.007211) central:(-0.009113) say:(-0.008241) wkwkwkwk:(-0.008432) pic:(-0.008241) i'm:(-0.008508) nice:(-0.008508)
#
# Country=us
# Naive Bayes
# like:(-8) get:(-8) i'm:(-8) u:(-8) can't:(-8) make:(-8) love:(-8) one:(-8) miss:(-8) go:(-8) happy:(-8) really:(-8) i'll:(-8) true:(-8) much:(-8) day:(-8) hope:(-8) feel:(-8) girl:(-8) people:(-8)
# Logistic Regression
# get:(-0.010946) like:(-0.009658) can't:(-0.007630) make:(-0.009890) i'll:(-0.009653) feel:(-0.008535) miss:(-0.010024) true:(0.086619) much:(0.086619) u:(-0.009721) really:(-0.009151) beginning:(-0.010568) find:(-0.009813) go:(-0.009813) dead:(-0.009596) chill:(-0.009253) sick:(-0.009540) better:(-0.009253) beer:(-0.008929) every:(-0.008929)
#
# Country=za
# Naive Bayes
# love:(-8) u:(-8) day:(-8) de:(-8) like:(-8) guys:(-8) happy:(-8) god:(-8) that's:(-8) makes:(-8) good:(-8) made:(-8) got:(-8) ur:(-8) today:(-8) old:(-8) award:(-8) feel:(-8) looking:(-8) town:(-8)
# Logistic Regression
# u:(-0.006773) de:(-0.010130) love:(0.069245) day:(-0.010013) makes:(-0.009767) ur:(-0.008688) guys:(-0.012497) that's:(-0.010139) made:(-0.010139) man:(-0.010341) good:(-0.009260) yebo:(-0.010089) cape:(-0.010826) south:(-0.010826) africa:(-0.009713) town:(-0.008075) loving:(-0.011460) @reflexwbc:(-0.008075) moments:(-0.009005) looking:(-0.009005)
